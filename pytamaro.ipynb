# %%
from pytamaro import rectangle, red, show_graphic

show_graphic(rectangle(100,200,red))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pytamaro import rectangle, red, show_graphic
#       3 show_graphic(rectangle(100,200,red))
#
# File ~/.local/lib/python3.11/site-packages/pytamaro/__init__.py:6
#       1 """
#       2 (Re-)Export names from this top-level module for the public API.
#       3 """
# ----> 6 from pytamaro.color import *
#       7 from pytamaro.color_functions import *
#       8 from pytamaro.color_names import *
#
# File ~/.local/lib/python3.11/site-packages/pytamaro/color.py:8
#       5 from dataclasses import dataclass
#       6 from functools import cached_property
# ----> 8 from skia import Color4f
#      10 from pytamaro.localization import translate
#      13 @dataclass(frozen=True)
#      14 class Color:
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory
